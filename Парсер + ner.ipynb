# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://rt.rbc.ru/'

# %%
page = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
print(page.status_code)

# %%
filteredNews = []
allNews = []

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <meta content="97bc592b27a9ada2d9a4bb418ed0ebed" name="csrf-token"/>
# <meta content="csrf_token" name="csrf-param"/>
# <meta content="rbс" name="Copyright"/>
# <title>Новости Татарстана :: РБК</title>
# <meta content="Новости Татарстана :: РБК" name="title">
# <meta content="«РосБизнесКонсалтинг» — ведущая российская компания, работающая в сферах масс-медиа и информационных технологий." name="description">
# ...

# %%
allNews = soup.findAll('a', class_='news-feed__item js-visited js-news-feed-item js-yandex-counter')

# %%
allNews = soup.findAll('span', class_='news-feed__item__title')

# %%
allNews
# Out:
# [<span class="news-feed__item__title news-feed__item_bold">
#          Курс евро на 27 мая<br/>
#          EUR ЦБ: 85,92
#          <span class="news-feed__item__change item__change_grow">
#                          (+0,04)
#          </span>
#  </span>, <span class="news-feed__item__title news-feed__item_bold">
#          Курс доллара на 27 мая<br/>
#          USD ЦБ: 79,97
#          <span class="news-feed__item__change item__change_fall">
#                          (-0,02)
#          </span>
#  </span>, <span class="news-feed__item__title">
#                      «Фокус — на успехе клиента»: как обновляют бренды в IT
#                  </span>, <span class="news-feed__item__title">
#                      Как новые телеком-сервисы меняют коммуникацию бизнеса с клиентами
#                  </span>, <span class="news-feed__item__title">
#                      В Ульяновской области пропал участник соревнований по парусному спорту
# ...

# %%
items = soup.find_all('span', class_ = 'news-feed__item__grid__content')

# %%
soup.append
# Out:
# <bound method PageElement.append of <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <meta content="97bc592b27a9ada2d9a4bb418ed0ebed" name="csrf-token"/>
# <meta content="csrf_token" name="csrf-param"/>
# <meta content="rbс" name="Copyright"/>
# <title>Новости Татарстана :: РБК</title>
# <meta content="Новости Татарстана :: РБК" name="title">
# <meta content="«РосБизнесКонсалтинг» — ведущая российская компания, работающая в сферах масс-медиа и информационных технологий." name="description">
# ...

# %%
for data in allNews:
    if data.find('span', class_='news-feed__item__date-text') is not None:
        filteredNews.append(data.text)

# %%
for data in filteredNews:
    print(data)
# Out:
#                     «Фокус — на успехе клиента»: как обновляют бренды в IT
#
#
# Тренды, 15:20
#
#
#
#
#
#
#                     Как новые телеком-сервисы меняют коммуникацию бизнеса с клиентами
#
#
# Тренды, 15:17
#
#
#
#
#
#
#                     В Ульяновской области пропал участник соревнований по парусному спорту
#
#
# Спорт, 15:13
#
#
#
#
#
#
#                     Вучич предложил сделать Вучевича своим преемником в правящей партии
#
#
# Политика, 15:08
#
#
#
#
#
#
#                     Гладков сообщил об отражении атаки беспилотника на село Поповка
#
#
# Политика, 15:02
#
#
#
#
#
#
#                     Как отечественные работодатели меняют кадровую политику
#
#
# Новая экономика, 14:59
#
#
#
#
#
#
#                     Павильоны рынка «Садовод» загорелись на юго-востоке Москвы
#
#
# Общество, 14:54
#
#
#
#
#
#
#                     Лавров заявил о сомнениях Лондона и Вашингтона в адекватности Киева
#
#
# Политика, 14:44
#
#
#
#
#
#
# ...

# %%
from nltk.tokenize import sent_tokenize

# %%
my_array = []
for data in filteredNews:
    sentences = sent_tokenize(data)
    my_array = my_array + sentences
    print(sentences)
# Out:
# ['\n\n\n\n                    Киев ответил на требования Москвы встречными условиями мира\n                \n\nПолитика,\xa014:20']
# ['\n\n\n\n                    Какие шансы дает предпринимателям новая ситуация в экономике\n                \n\nНовая экономика,\xa014:17']
# ['\n\n\n\n                    Как спрос на БАДы стимулирует рынок онлайн-торговли\n                \n\nРБК+,\xa014:16']
# ['\n\n\n\n                    Новый этап развития: как изменится рынок NFT в 2023 году\n                \n\nКрипто,\xa014:16']
# ['\n\n\n\n                    В «Челси» заявили об отсутствии заинтересованности в трансфере Захаряна\n                \n\nСпорт,\xa014:08']
# ['\n\n\n\n                    Патриарх запретил в служении главу совета РПЦ по искусству из-за «Троицы»\n                \n\nОбщество,\xa013:56']
# ['\n\n\n\n                    В Курской области после обстрела погиб строитель\n                \n\nПолитика,\xa013:42']
# ...

# %%
my_array[1]
# Out:
# '\n\n\n\n                    Какие шансы дает предпринимателям новая ситуация в экономике\n                \n\nНовая экономика,\xa014:17'

# %%
import numpy as np

# %%
clean_array = [string.replace('\n', '') for string in my_array]
print(clean_array)
# Out:
# ['                    Киев ответил на требования Москвы встречными условиями мира                Политика,\xa014:20', '                    Какие шансы дает предпринимателям новая ситуация в экономике                Новая экономика,\xa014:17', '                    Как спрос на БАДы стимулирует рынок онлайн-торговли                РБК+,\xa014:16', '                    Новый этап развития: как изменится рынок NFT в 2023 году                Крипто,\xa014:16', '                    В «Челси» заявили об отсутствии заинтересованности в трансфере Захаряна                Спорт,\xa014:08', '                    Патриарх запретил в служении главу совета РПЦ по искусству из-за «Троицы»                Общество,\xa013:56', '                    В Курской области после обстрела погиб строитель                Политика,\xa013:42', '                    Холанда признали лучшим игроком сезона в Английской премьер-лиге                Спорт,\xa013:29', '                    Минобороны сообщило об атаке на Су-
# ...

# %%
length = len(my_array)
print(length)
# Out:
# 14

# %%
from nltk.tokenize import word_tokenize

# %%
tokenized_words = [word_tokenize(s) for s in my_array]

# %%
tokenized_words[1]
# Out:
# ['Какие',
#  'шансы',
#  'дает',
#  'предпринимателям',
#  'новая',
#  'ситуация',
#  'в',
#  'экономике',
#  'Новая',
#  'экономика',
#  ',',
#  '14:17']

# %%
from natasha import (
    Segmenter,
    MorphVocab,    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger, 
    PER,
    NamesExtractor,
    Doc
)

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

doc = Doc(my_array[3])
doc
# Out:
# Doc(text='\n\n\n\n                    Новый этап развития: ...)

# %%
from natasha import DatesExtractor
morph_vocab = MorphVocab()
extractor2 = DatesExtractor(morph_vocab)

matches = extractor2(my_array[3])

for match in matches:
    print(match.fact)
# Out:
# Date(year=2023, month=None, day=None)

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)

# %%
from tabulate import tabulate

# %%
data = [["Mavs", 99], 
        ["Suns", 91], 
        ["Spurs", 94], 
        ["Nets", 88]]
  
#define header names
col_names = ["Новость ", "Время"]
  
#display table
print(tabulate(data, headers=col_names))
# Out:
# Team      Points
# ------  --------
# Mavs          99
# Suns          91
# Spurs         94
# Nets          88

# %%
#нужное

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.vesti.ru/news'

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
bs = BeautifulSoup(response.text,"lxml")
print(bs)
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <link href="/i/apple-icon-57x57.png?v=1" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/i/apple-icon-60x60.png?v=1" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/i/apple-icon-72x72.png?v=1" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/i/apple-icon-76x76.png?v=1" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/i/apple-icon-114x114.png?v=1" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/i/apple-icon-120x120.png?v=1" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/i/apple-icon-144x144.png?v=1" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/i/apple-icon-152x152.png?v=1" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/i/apple-icon-180x180.png?v=1" rel="apple-touch-icon" sizes="180x180"/>
# ...

# %%
allNews = bs.findAll('div', 'list__item')

# %%
print(allNews)
# Out:
# [<div class="list__item">
# <a class="list__pic-wrapper vgtrk-lazy-preloader" href="/article/3387830">
# <img alt="Девочка из Енакиева получила щенка от Путина" class="list__pic vgtrk-lazy" data-src="https://cdn-st1.rtr-vesti.ru/vh/pictures/lw/426/574/6.jpg"/>
# </a>
# <div class="list__info">
# <div class="list__data">
# <div class="list__date">
#                                     04 июня 2023
#                                 </div>
# <div class="list__time">
#                                     18:08
#                                 </div>
# <div class="list__subtitle">
# <span class="list__src"></span>
# </div>
# </div>
# <h3 class="list__title">
# <a href="/article/3387830">Девочка из Енакиева получила щенка от Путина</a>
# </h3>
# <div class="list__icon">
# <a class="list__icon-play" href="/video/2626693"></a>
# </div>
# </div>
# </div>, <div class="list__item">
# <a class="list__pic-wrapper vgtrk-lazy-preloader" href="/article/3387811">
# ...

# %%
length = len(allNews)
print(length)
# Out:
# 20

# %%
arr_data1 = []
for item in allNews:
    temp = item.find('div', 'list__date')
    temp = temp.text
    #lstrip(temp) 
   # rstrip(temp)
    #print(temp)
   # print(type(temp))
    #print (temp)
    #arr_data = arr_data + temp
    arr_data1.append(temp)
print (arr_data1)
# Out:
# ['\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                                    04 июня 2023\n                                ', '\n                          
# ...

# %%
arr_data1 = [line.rstrip() for line in arr_data1]
arr_data1
# Out:
# ['\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
#  '\n                                    04 июня 2023',
# ...

# %%
new_array1 = []
for string in arr_data1:
    new_string = string.replace("\n", "")[36:]
    new_array1.append(new_string)

print(new_array1)
# Out:
# ['04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023', '04 июня 2023']

# %%
s1=arr_data1[1].replace("\n", "")[36:]
#s1=arr_data[1].replace(" ", "")
#s1 = s1[36:]
print (s1)
# Out:
# 04 июня 2023

# %%
arr_data2 = []
for item in allNews:
    temp = item.find('h3', 'list__title')
    temp = temp.text
    arr_data2.append(temp)
print (arr_data2)
# Out:
# ['\nДевочка из Енакиева получила щенка от Путина\n', '\nВ КНР открылся первый после пандемии Фестиваль акации\n', '\nФерстаппен стал победителем Гран-при Испании\n', '\nЭкс-начальник свердловской ГИБДД погиб после падения с высоты\n', '\nБольной деменцией Брюс Уиллис прокатился на аттракционе в Диснейленде\n', '\nМухова отменила российский четвертьфинал на Roland Garros\n', '\nВ белгородском селе завязался бой с украинской ДРГ\n', '\nСтолтенберг: Швеция выполнила все обязательства для вступления в НАТО\n', '\nОбъявлены победители Х Забайкальского международного кинофестиваля\n', '\nВ нападении на Белгородскую область участвовали польские наемники\n', '\nВ России продают BMW принца Кувейта\n', '\nГроссмейстер Сергей Карякин сыграл в шахматы с бойцами СВО\n', '\nАльтернативы нет: Россия должна довести спецоперацию до конца\n', '\nВ Варшаве проходит полумиллионная антиправительственная демонстрация\n', '\nСуданский спецназ сбил МиГ после возобновления боев\n', '\nSpaceX вывела на орбиту
# ...

# %%
arr_data2 = [line.rstrip() for line in arr_data2]
arr_data2
# Out:
# ['\nДевочка из Енакиева получила щенка от Путина',
#  '\nВ КНР открылся первый после пандемии Фестиваль акации',
#  '\nФерстаппен стал победителем Гран-при Испании',
#  '\nЭкс-начальник свердловской ГИБДД погиб после падения с высоты',
#  '\nБольной деменцией Брюс Уиллис прокатился на аттракционе в Диснейленде',
#  '\nМухова отменила российский четвертьфинал на Roland Garros',
#  '\nВ белгородском селе завязался бой с украинской ДРГ',
#  '\nСтолтенберг: Швеция выполнила все обязательства для вступления в НАТО',
#  '\nОбъявлены победители Х Забайкальского международного кинофестиваля',
#  '\nВ нападении на Белгородскую область участвовали польские наемники',
#  '\nВ России продают BMW принца Кувейта',
#  '\nГроссмейстер Сергей Карякин сыграл в шахматы с бойцами СВО',
#  '\nАльтернативы нет: Россия должна довести спецоперацию до конца',
#  '\nВ Варшаве проходит полумиллионная антиправительственная демонстрация',
#  '\nСуданский спецназ сбил МиГ после возобновления боев',
# ...

# %%
new_array2 = []
for string in arr_data2:
    new_string2 = string.replace("\n", "")
    new_array2.append(new_string2)

print(new_array2)
# Out:
# ['Девочка из Енакиева получила щенка от Путина', 'В КНР открылся первый после пандемии Фестиваль акации', 'Ферстаппен стал победителем Гран-при Испании', 'Экс-начальник свердловской ГИБДД погиб после падения с высоты', 'Больной деменцией Брюс Уиллис прокатился на аттракционе в Диснейленде', 'Мухова отменила российский четвертьфинал на Roland Garros', 'В белгородском селе завязался бой с украинской ДРГ', 'Столтенберг: Швеция выполнила все обязательства для вступления в НАТО', 'Объявлены победители Х Забайкальского международного кинофестиваля', 'В нападении на Белгородскую область участвовали польские наемники', 'В России продают BMW принца Кувейта', 'Гроссмейстер Сергей Карякин сыграл в шахматы с бойцами СВО', 'Альтернативы нет: Россия должна довести спецоперацию до конца', 'В Варшаве проходит полумиллионная антиправительственная демонстрация', 'Суданский спецназ сбил МиГ после возобновления боев', 'SpaceX вывела на орбиту 22 спутника Starlink нового поколения', 'В России составлен т
# ...

# %%
arr_data3 = []
for item in allNews:
    temp = item.find('div', 'list__time')
    temp = temp.text
    arr_data3.append(temp)
print (arr_data3)
# Out:
# ['\n                                    18:08\n                                ', '\n                                    18:07\n                                ', '\n                                    18:01\n                                ', '\n                                    17:54\n                                ', '\n                                    17:49\n                                ', '\n                                    17:42\n                                ', '\n                                    17:18\n                                ', '\n                                    17:17\n                                ', '\n                                    17:17\n                                ', '\n                                    17:00\n                                ', '\n                                    16:55\n                                ', '\n                                    16:45\n                                ', '\n                      
# ...

# %%
arr_data3 = [line.rstrip() for line in arr_data3]
arr_data3
# Out:
# ['\n                                    18:08',
#  '\n                                    18:07',
#  '\n                                    18:01',
#  '\n                                    17:54',
#  '\n                                    17:49',
#  '\n                                    17:42',
#  '\n                                    17:18',
#  '\n                                    17:17',
#  '\n                                    17:17',
#  '\n                                    17:00',
#  '\n                                    16:55',
#  '\n                                    16:45',
#  '\n                                    16:41',
#  '\n                                    16:32',
#  '\n                                    16:30',
#  '\n                                    16:29',
#  '\n                                    16:22',
#  '\n                                    16:15',
#  '\n                                    15:40',
#  '\n                                    15:39']

# %%
s1=arr_data3[1].replace("\n", "")[36:]
#s1=arr_data[1].replace(" ", "")
#s1 = s1[36:]
print (s1)
# Out:
# 18:07

# %%
new_array3 = []
for string in arr_data3:
    new_string3 = string.replace("\n", "")[36:]
    new_array3.append(new_string3)

print(new_array3)
# Out:
# ['18:08', '18:07', '18:01', '17:54', '17:49', '17:42', '17:18', '17:17', '17:17', '17:00', '16:55', '16:45', '16:41', '16:32', '16:30', '16:29', '16:22', '16:15', '15:40', '15:39']

# %%
import numpy as np
import pandas as pd

# Сохраняем массивы в виде столбцов DataFrame
df = pd.DataFrame({'Дата публикации новости': new_array1,'Время публикации новости': new_array3, 'Заголовок новости': new_array2})
# Выводим таблицу на экран
print(df)
# Out:
#    Дата публикации новости Время публикации новости  \
# 0             04 июня 2023                    18:08
# 1             04 июня 2023                    18:07
# 2             04 июня 2023                    18:01
# 3             04 июня 2023                    17:54
# 4             04 июня 2023                    17:49
# 5             04 июня 2023                    17:42
# 6             04 июня 2023                    17:18
# 7             04 июня 2023                    17:17
# 8             04 июня 2023                    17:17
# 9             04 июня 2023                    17:00
# 10            04 июня 2023                    16:55
# 11            04 июня 2023                    16:45
# 12            04 июня 2023                    16:41
# 13            04 июня 2023                    16:32
# 14            04 июня 2023                    16:30
# 15            04 июня 2023                    16:29
# 16            04 июня 2023                    16:22
# ...

# %%
import os

# %%
df.to_csv('my_tablenews.csv', index=False, mode='a', header=not os.path.isfile('my_tablenews.csv'))

# %%
length = len(df)
print(length)
# Out:
# 20

# %%
df.loc[0:length, 'Заголовок новости']
# Out:
# 0          Девочка из Енакиева получила щенка от Путина
# 1     В КНР открылся первый после пандемии Фестиваль...
# 2          Ферстаппен стал победителем Гран-при Испании
# 3     Экс-начальник свердловской ГИБДД погиб после п...
# 4     Больной деменцией Брюс Уиллис прокатился на ат...
# 5     Мухова отменила российский четвертьфинал на Ro...
# 6     В белгородском селе завязался бой с украинской...
# 7     Столтенберг: Швеция выполнила все обязательств...
# 8     Объявлены победители Х Забайкальского междунар...
# 9     В нападении на Белгородскую область участвовал...
# 10                  В России продают BMW принца Кувейта
# 11    Гроссмейстер Сергей Карякин сыграл в шахматы с...
# 12    Альтернативы нет: Россия должна довести спецоп...
# 13    В Варшаве проходит полумиллионная антиправител...
# 14    Суданский спецназ сбил МиГ после возобновления...
# 15    SpaceX вывела на орбиту 22 спутника Starlink н...
# 16            В России составлен топ-5 автоновинок июня
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#arr_data = []
#for string in df.loc[0:length-1, 'Заголовок новости']:
#    matches = extractor2(string)
#    for match in matches:
#        print(match.fact)
#        arr_data.append(match.fact) 
 #       dfdata = pd.DataFrame({'Дата новости': arr_data})
    #df.loc[string, 'Дата'] = match.fact
#dfdata

# %%
table = pd.DataFrame({'Заголовок новости тест': ['Иван Перович 27 ноября', 'Борис 12 декабря 2023 года', 'Владимир 12 рублей', 'Галина 40 тысяч евро 27 декабря'], 'Тест':['1','2','3','4']})

# %%
table
# Out:
#             Заголовок новости тест Тест
# 0           Иван Перович 27 ноября    1
# 1       Борис 12 декабря 2023 года    2
# 2               Владимир 12 рублей    3
# 3  Галина 40 тысяч евро 27 декабря    4

# %%
length2 = len(table)
print(length2)
# Out:
# 4

# %%
arr_data2 = [None] * length2
i = -1
for string in table.loc[0:length2-1, 'Заголовок новости тест']:
    matches = extractor(string)
    i=i+1
    for match in matches:
        print (string)
        if(string !=''):
            a = str(match.fact)
            print (match.fact)
            arr_data2[i] = a
    dfdata2 = pd.DataFrame({'Деньги в новости': arr_data2})
dfdata2
# Out:
# Владимир 12 рублей
# Money(amount=12, currency='RUB')
# Галина 40 тысяч евро 27 декабря
# Money(amount=40000.27, currency='EUR')
#                          Деньги в новости
# 0                                    None
# 1                                    None
# 2        Money(amount=12, currency='RUB')
# 3  Money(amount=40000.27, currency='EUR')

# %%
table['Деньги в новости']= dfdata2['Деньги в новости']

# %%
table
# Out:
#             Заголовок новости тест Тест  \
# 0           Иван Перович 27 ноября    1
# 1       Борис 12 декабря 2023 года    2
# 2               Владимир 12 рублей    3
# 3  Галина 40 тысяч евро 27 декабря    4
#
#                          Деньги в новости
# 0                                    None
# 1                                    None
# 2        Money(amount=12, currency='RUB')
# 3  Money(amount=40000.27, currency='EUR')

# %%
#С реальными данными

# %%
arr_data = [None] * length
i = -1
for string in df.loc[0:length2-1, 'Заголовок новости']:
    matches = extractor2(string)
    i=i+1
    for match in matches:
        if(string !=''):
            a = str(match.fact)
            arr_data[i] = a
    dfdata = pd.DataFrame({'Дата новости': arr_data})
dfdata
# Out:
#    Дата новости
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None

# %%
df['Дата в новости']= dfdata['Дата новости']
df
# Out:
#    Дата публикации новости Время публикации новости  \
# 0             04 июня 2023                    18:08
# 1             04 июня 2023                    18:07
# 2             04 июня 2023                    18:01
# 3             04 июня 2023                    17:54
# 4             04 июня 2023                    17:49
# 5             04 июня 2023                    17:42
# 6             04 июня 2023                    17:18
# 7             04 июня 2023                    17:17
# 8             04 июня 2023                    17:17
# 9             04 июня 2023                    17:00
# 10            04 июня 2023                    16:55
# 11            04 июня 2023                    16:45
# 12            04 июня 2023                    16:41
# 13            04 июня 2023                    16:32
# 14            04 июня 2023                    16:30
# 15            04 июня 2023                    16:29
# 16            04 июня 2023                    16:22
# ...

# %%
arr_price = [None] * length
i = -1
for string in df.loc[0:length2-1, 'Заголовок новости']:
    matches = extractor(string)
    i=i+1
    for match in matches:
        if(string !=''):
            a = str(match.fact)
            arr_price[i] = a
    dfprice = pd.DataFrame({'Деньги в новости': arr_price})
dfprice
# Out:
#    Деньги в новости
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8              None
# 9              None
# 10             None
# 11             None
# 12             None
# 13             None
# 14             None
# 15             None
# 16             None
# 17             None
# 18             None
# 19             None

# %%
df['Деньги в новости']= dfprice['Деньги в новости']
df
# Out:
#    Дата публикации новости Время публикации новости  \
# 0             04 июня 2023                    18:08
# 1             04 июня 2023                    18:07
# 2             04 июня 2023                    18:01
# 3             04 июня 2023                    17:54
# 4             04 июня 2023                    17:49
# 5             04 июня 2023                    17:42
# 6             04 июня 2023                    17:18
# 7             04 июня 2023                    17:17
# 8             04 июня 2023                    17:17
# 9             04 июня 2023                    17:00
# 10            04 июня 2023                    16:55
# 11            04 июня 2023                    16:45
# 12            04 июня 2023                    16:41
# 13            04 июня 2023                    16:32
# 14            04 июня 2023                    16:30
# 15            04 июня 2023                    16:29
# 16            04 июня 2023                    16:22
# ...

# %%
length = len(df)
print(length)
# Out:
# 20

# %%
from natasha import (
    Segmenter,
    MorphVocab,    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger, 
    PER,
    NamesExtractor,
    Doc
)

# %%
from navec import Navec
from slovnet import NER
navec = Navec.load('./navec_news_v1_1B_250K_300d_100q.tar')
ner = NER.load('./slovnet_ner_news_v1.tar')
ner.navec(navec)
# Out:
# NER(
#     infer=NERInfer(
#         model=NER(
#             emb=WordShapeEmbedding(
#                 word=NavecEmbedding(
#                     id='news_v1_1B_250K_300d_100q',
#                     indexes=Weight(
#                         shape=[250002, 100],
#                         dtype='uint8',
#                         array=array([[176, 222, 248, ..., 244, 183, 191],
#                                [215, 200, 168, ..., 120, 217,  21],
#                                [ 83, 174,  54, ..., 106,  88, 251],
#                                ...,
#                                [133, 125, 123, ..., 124,  94,  24],
#                                [183,  49, 180, ..., 151, 167,  68],
#                                [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
#                     ),
#                     codes=Weight(
#                         shape=[100, 256, 3],
#                         dtype='float32',
# ...

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %%
arr_per = [None] * length
arr_org = [None] * length
arr_loc = [None] * length
i = -1
for string in df.loc[0:length-1, 'Заголовок новости']:
    i=i+1
    doc = Doc(string)
    markup = ner(string)
    #print(markup)
    persons = [string[s.start:s.stop] for s in markup.spans if s.type=='PER']
    locations = [string[s.start:s.stop] for s in markup.spans if s.type=='LOC']
    organizations = [string[s.start:s.stop] for s in markup.spans if s.type=='ORG']
    if(persons !=''):
        a = persons
        arr_per[i] = a
        #arr_per[i] = persons
    dfper = pd.DataFrame({'Персонаж': arr_per})   
    if(organizations !=''):
        b = organizations
        arr_org[i] = b
        #arr_org[i] = organizations
    dforg = pd.DataFrame({'Локация': arr_org})
    
    if(locations !=''):
        b = locations
        arr_loc[i] = b
        #arr_loc[i] = locations
    dfloc = pd.DataFrame({'Организация': arr_loc})
dfloc
# Out:
#                Организация
# 0               [Енакиева]
# 1                    [КНР]
# 2                [Испании]
# 3                       []
# 4            [Диснейленде]
# 5                       []
# 6                       []
# 7                 [Швеция]
# 8         [Забайкальского]
# 9   [Белгородскую область]
# 10       [России, Кувейта]
# 11                      []
# 12                [Россия]
# 13               [Варшаве]
# 14                      []
# 15                      []
# 16                [России]
# 17                      []
# 18                      []
# 19                      []

# %%
import pandas as pd
df['Персонаж'] = arr_per
df['Локация'] = arr_loc
df['Организация'] = arr_org
df
# Out:
#    Дата публикации новости Время публикации новости  \
# 0             04 июня 2023                    18:08
# 1             04 июня 2023                    18:07
# 2             04 июня 2023                    18:01
# 3             04 июня 2023                    17:54
# 4             04 июня 2023                    17:49
# 5             04 июня 2023                    17:42
# 6             04 июня 2023                    17:18
# 7             04 июня 2023                    17:17
# 8             04 июня 2023                    17:17
# 9             04 июня 2023                    17:00
# 10            04 июня 2023                    16:55
# 11            04 июня 2023                    16:45
# 12            04 июня 2023                    16:41
# 13            04 июня 2023                    16:32
# 14            04 июня 2023                    16:30
# 15            04 июня 2023                    16:29
# 16            04 июня 2023                    16:22
# ...

# %%
df[0:12]
# Out:
#    Дата публикации новости Время публикации новости  \
# 0             04 июня 2023                    18:08
# 1             04 июня 2023                    18:07
# 2             04 июня 2023                    18:01
# 3             04 июня 2023                    17:54
# 4             04 июня 2023                    17:49
# 5             04 июня 2023                    17:42
# 6             04 июня 2023                    17:18
# 7             04 июня 2023                    17:17
# 8             04 июня 2023                    17:17
# 9             04 июня 2023                    17:00
# 10            04 июня 2023                    16:55
# 11            04 июня 2023                    16:45
#
#                                     Заголовок новости Дата в новости  \
# 0        Девочка из Енакиева получила щенка от Путина           None
# 1   В КНР открылся первый после пандемии Фестиваль...           None
# 2        Ферстаппен стал победителем Гран-при Испании           None
# ...

# %%
df[0:12].to_csv('results.csv', index=False, mode='a', header=not os.path.isfile('results.csv'))

# %%
# !pip install numpy
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\asus\anaconda3\lib\site-packages)

# %%
print(type(dfloc))
# Out:
# <class 'pandas.core.series.Series'>

# %%
import numpy as np
my_array = np.array(organizations)
print(my_array)
# Out:
# []

# %%
#df.to_csv('my_table.csv', index=False)

# %%
df.to_csv('my_table2.csv', index=False, mode='a', header=not os.path.isfile('my_table2.csv'))

# %%
df2 = pd.DataFrame({'Заголовок новости':new_array2})

# %%
df2.to_csv('my_table3.csv', index=False, mode='a', header=not os.path.isfile('my_table3.csv'))

# %%
with open('my_table3.csv', 'r', encoding='utf-8') as f:
    data2 = f.read()

# %%
data2
# Out:
# 'Заголовок новости\nОдин человек погиб в ходе обстрела Шебекина\nВ России учрежден орден Юрия Гагарина\nГлава РАН предсказал рост мощности нейросетей в 100 тысяч раз\nБрянский губернатор опроверг информацию о вторжении ДРГ\nСербская армия разворачивается на границе с Косовом\nХоккеисты Канады вышли в финал чемпионата мира\nПочему важно слушать бортпроводника\nВсе меры поддержки для предпринимателей\nСемь человек пострадали в ДТП с автобусом в Ульяновской области\n"Песков: Запад все больше вовлекается в конфликт, но СВО будет продолжаться"\nСамодельный мотопараплан разбился в Комсомольске-на-Амуре\nУкраина смягчит правила посещения туристами Чернобыльской АЭС\nЗа сутки в Белгородской области зафиксировали 250 прилетов\n"Юшин и Мишкич принесли ""Уралу"" победу в Химках"\nПравила парковки в Москве могут смягчить\nМинобороны: за сутки уничтожено до 500 военнослужащих противника\n"Захар Прилепин сообщил, сколько получил переломов в результате покушения"\nБездомный челябинец выбросил в мус
# ...

# %%
import os

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(data2)

# %%
#data = nlp(new_array2[0])

# %%
doc
# Out:
# Заголовок новости
# Один человек погиб в ходе обстрела Шебекина
# В России учрежден орден Юрия Гагарина
# Глава РАН предсказал рост мощности нейросетей в 100 тысяч раз
# Брянский губернатор опроверг информацию о вторжении ДРГ
# Сербская армия разворачивается на границе с Косовом
# Хоккеисты Канады вышли в финал чемпионата мира
# Почему важно слушать бортпроводника
# Все меры поддержки для предпринимателей
# Семь человек пострадали в ДТП с автобусом в Ульяновской области
# "Песков: Запад все больше вовлекается в конфликт, но СВО будет продолжаться"
# Самодельный мотопараплан разбился в Комсомольске-на-Амуре
# Украина смягчит правила посещения туристами Чернобыльской АЭС
# За сутки в Белгородской области зафиксировали 250 прилетов
# "Юшин и Мишкич принесли ""Уралу"" победу в Химках"
# Правила парковки в Москве могут смягчить
# Минобороны: за сутки уничтожено до 500 военнослужащих противника
# "Захар Прилепин сообщил, сколько получил переломов в результате покушения"
# ...

# %%
print(type(doc))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %%
from spacy import displacy

# %%
#doc = nlp(data)
#spacy.displacy.render(doc, style='dep', jupyter=True)

# %%
for ent in doc.ents:
    if ent.label_ == "DATE":
        print(ent.text, "-->", "дата")
    elif ent.label_ == "MONEY":
        print(ent.text, "-->", "деньги")

# %%
def lemmat(text):
    doc = rus_model(text)
    tokens = [token.lemma_ for token in doc]
    return " ".join(tokens)

# %%
from spacy import displacy
for ent in doc.ents:
    print(ent.text,ent.start_char, ent.end_char, ent.label_)  
displacy.render(doc, style = 'ent')
# Out:
# Заголовок 0 9 GPE
# Один 18 22 ORG
# России 64 70 NORP
# Юрия Гагарина 86 99 ORG
# Глава РАН 100 109 ORG
# 100 148 151 CARDINAL
# Брянский 162 170 NORP
# ДРГ
# Сербская армия разворачивается на границе 214 259 ORG
# Косовом
# Хоккеисты Канады 262 286 ORG
# в финал чемпионата 293 311 PERSON
# Почему важно 317 329 PERSON
# предпринимателей
#  376 393 ORG
# Песков 458 464 PERSON
# Комсомольске 570 582 ORG
# Украина 592 599 ORG
# Чернобыльской АЭС
# За 636 656 PERSON
# 250 700 703 CARDINAL
# Уралу 739 744 WORK_OF_ART
# Правила 764 771 LOC
# Минобороны 805 815 PERSON
# 500 840 843 CARDINAL
# Захар Прилепин 871 885 PERSON
# сколько 895 902 CARDINAL
# Украинский 993 1003 GPE
# Белгородской 1024 1036 ORG
# Замуправделами Патриархии 1045 1070 PERSON
# Леонида 1095 1102 GPE
# Что 1119 1122 GPE
# 1 1135 1136 CARDINAL
# Песков 1142 1148 ORG
# ВСУ 1172 1175 ORG
# 78 1186 1188 CARDINAL
# погранпунктам в Белгородской 1201 1229 PERSON
# Микроавтобус 1239 1251 PERSON
# Волгограде 1269 1279 ORG
# ...

# %%
data2 = nlp(new_array2[3])

# %%
data2
# Out:
# Микроавтобус влетел в столб в Волгограде, один человек погиб

# %%
for ent in doc.ents:
    if ent.label_ == "DATE":
        print(ent.text, "-->", "дата")
    elif ent.label_ == "MONEY":
        print(ent.text, "-->", "деньги")

# %%
def lemmat(text):
    doc = rus_model(text)
    tokens = [token.lemma_ for token in doc]
    return " ".join(tokens)

# %%
from spacy import displacy
for ent in doc.ents:
    print(ent.text,ent.start_char, ent.end_char, ent.label_)  
displacy.render(doc, style = 'ent')
# Out:
# Микроавтобус 0 12 PERSON
# в столб в 20 29 PERSON
# Волгограде 30 40 ORG
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Микроавтобус
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  влетел
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     в столб в
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Волгограде
# ...

# %%
from natasha import (
    Segmenter,
    MorphVocab,    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger, 
    PER,
    NamesExtractor,
    Doc
)

# %%
with open('my_table3.csv', 'r', encoding='utf-8') as f:
    data3 = f.read()
data3 = data3[18:]
data3
# Out:
# 'Один человек погиб в ходе обстрела Шебекина\nВ России учрежден орден Юрия Гагарина\nГлава РАН предсказал рост мощности нейросетей в 100 тысяч раз\nБрянский губернатор опроверг информацию о вторжении ДРГ\nСербская армия разворачивается на границе с Косовом\nХоккеисты Канады вышли в финаЫл чемпионата мира\nПочему важно слушать бортпроводника\nВсе меры поддержки для предпринимателей\nСемь человек пострадали в ДТП с автобусом в Ульяновской области\n"Песков: Запад все больше вовлекается в конфликт, но СВО будет продолжаться"\nСамодельный мотопараплан разбился в Комсомольске-на-Амуре\nУкраина смягчит правила посещения туристами Чернобыльской АЭС\nЗа сутки в Белгородской области зафиксировали 250 прилетов\n"Юшин и Мишкич принесли ""Уралу"" победу в Химках"\nПравила парковки в Москве могут смягчить\nМинобороны: за сутки уничтожено до 500 военнослужащих противника\n"Захар Прилепин сообщил, сколько получил переломов в результате покушения"\nБездомный челябинец выбросил в мусорку младенца\nУкр
# ...

# %%
data3 = data3.replace("\n", ". ")
data3
# Out:
# 'Один человек погиб в ходе обстрела Шебекина. В России учрежден орден Юрия Гагарина. Глава РАН предсказал рост мощности нейросетей в 100 тысяч раз. Брянский губернатор опроверг информацию о вторжении ДРГ. Сербская армия разворачивается на границе с Косовом. Хоккеисты Канады вышли в финаЫл чемпионата мира. Почему важно слушать бортпроводника. Все меры поддержки для предпринимателей. Семь человек пострадали в ДТП с автобусом в Ульяновской области. "Песков: Запад все больше вовлекается в конфликт, но СВО будет продолжаться". Самодельный мотопараплан разбился в Комсомольске-на-Амуре. Украина смягчит правила посещения туристами Чернобыльской АЭС. За сутки в Белгородской области зафиксировали 250 прилетов. "Юшин и Мишкич принесли ""Уралу"" победу в Химках". Правила парковки в Москве могут смягчить. Минобороны: за сутки уничтожено до 500 военнослужащих противника. "Захар Прилепин сообщил, сколько получил переломов в результате покушения". Бездомный челябинец выбросил в мусорку младенца. Укр
# ...

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

#doc = Doc(data3)

# %%
print(type(doc))
# Out:
# <class 'natasha.doc.Doc'>

# %%
#цены

from natasha import MoneyExtractor
morph_vocab = MorphVocab()
extractor = MoneyExtractor(morph_vocab)

#matches = extractor(data3)

#for match in matches:
 #   print(match.fact)

# %%
#даты

from natasha import DatesExtractor
morph_vocab = MorphVocab()
extractor2 = DatesExtractor(morph_vocab)

#matches = extractor2(data3)

#for match in matches:
#    print(match.fact)

# %%
doc.segment(segmenter)
print(doc.tokens)
print(doc.sents)
# Out:
# [DocToken(stop=4, text='Один'), DocToken(start=5, stop=12, text='человек'), DocToken(start=13, stop=18, text='погиб'), DocToken(start=19, stop=20, text='в'), DocToken(start=21, stop=25, text='ходе'), DocToken(start=26, stop=34, text='обстрела'), DocToken(start=35, stop=43, text='Шебекина'), DocToken(start=43, stop=44, text='.'), DocToken(start=45, stop=46, text='В'), DocToken(start=47, stop=53, text='России'), DocToken(start=54, stop=62, text='учрежден'), DocToken(start=63, stop=68, text='орден'), DocToken(start=69, stop=73, text='Юрия'), DocToken(start=74, stop=82, text='Гагарина'), DocToken(start=82, stop=83, text='.'), DocToken(start=84, stop=89, text='Глава'), DocToken(start=90, stop=93, text='РАН'), DocToken(start=94, stop=104, text='предсказал'), DocToken(start=105, stop=109, text='рост'), DocToken(start=110, stop=118, text='мощности'), DocToken(start=119, stop=129, text='нейросетей'), DocToken(start=130, stop=131, text='в'), DocToken(start=132, stop=135, text='100'), DocToken(
# ...

# %%
doc.tag_morph(morph_tagger)
print(doc.tokens)
doc.sents[0].morph.print()
# Out:
# [DocToken(stop=4, text='Один', pos='NUM', feats=<Nom,Masc,Sing>), DocToken(start=5, stop=12, text='человек', pos='NOUN', feats=<Anim,Nom,Masc,Sing>), DocToken(start=13, stop=18, text='погиб', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>), DocToken(start=19, stop=20, text='в', pos='ADP'), DocToken(start=21, stop=25, text='ходе', pos='NOUN', feats=<Inan,Loc,Masc,Sing>), DocToken(start=26, stop=34, text='обстрела', pos='NOUN', feats=<Inan,Gen,Masc,Sing>), DocToken(start=35, stop=43, text='Шебекина', pos='PROPN', feats=<Anim,Nom,Masc,Sing>), DocToken(start=43, stop=44, text='.', pos='PUNCT'), DocToken(start=45, stop=46, text='В', pos='ADP'), DocToken(start=47, stop=53, text='России', pos='PROPN', feats=<Inan,Loc,Fem,Sing>), DocToken(start=54, stop=62, text='учрежден', pos='VERB', feats=<Perf,Masc,Sing,Past,Short,Part,Pass>), DocToken(start=63, stop=68, text='орден', pos='NOUN', feats=<Inan,Nom,Masc,Sing>), DocToken(start=69, stop=73, text='Юрия', pos='PROPN', feats=<Anim,Gen,Masc,
# ...

# %%
for token in doc.tokens:
    token.lemmatize(morph_vocab)
    
print(doc.tokens)
{_.text: _.lemma for _ in doc.tokens}
# Out:
# [DocToken(stop=4, text='Один', pos='NUM', feats=<Nom,Masc,Sing>, lemma='один'), DocToken(start=5, stop=12, text='человек', pos='NOUN', feats=<Anim,Nom,Masc,Sing>, lemma='человек'), DocToken(start=13, stop=18, text='погиб', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>, lemma='погибнуть'), DocToken(start=19, stop=20, text='в', pos='ADP', lemma='в'), DocToken(start=21, stop=25, text='ходе', pos='NOUN', feats=<Inan,Loc,Masc,Sing>, lemma='ход'), DocToken(start=26, stop=34, text='обстрела', pos='NOUN', feats=<Inan,Gen,Masc,Sing>, lemma='обстрел'), DocToken(start=35, stop=43, text='Шебекина', pos='PROPN', feats=<Anim,Nom,Masc,Sing>, lemma='шебекино'), DocToken(start=43, stop=44, text='.', pos='PUNCT', lemma='.'), DocToken(start=45, stop=46, text='В', pos='ADP', lemma='в'), DocToken(start=47, stop=53, text='России', pos='PROPN', feats=<Inan,Loc,Fem,Sing>, lemma='россия'), DocToken(start=54, stop=62, text='учрежден', pos='VERB', feats=<Perf,Masc,Sing,Past,Short,Part,Pass>, lemma='учред
# ...

# %%
doc.parse_syntax(syntax_parser)
print(doc.tokens)
doc.sents[0].syntax.print()
# Out:
# [DocToken(stop=4, text='Один', id='1_1', head_id='1_2', rel='nummod', pos='NUM', feats=<Nom,Masc,Sing>, lemma='один'), DocToken(start=5, stop=12, text='человек', id='1_2', head_id='1_3', rel='nsubj', pos='NOUN', feats=<Anim,Nom,Masc,Sing>, lemma='человек'), DocToken(start=13, stop=18, text='погиб', id='1_3', head_id='1_0', rel='root', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>, lemma='погибнуть'), DocToken(start=19, stop=20, text='в', id='1_4', head_id='1_6', rel='case', pos='ADP', lemma='в'), DocToken(start=21, stop=25, text='ходе', id='1_5', head_id='1_4', rel='fixed', pos='NOUN', feats=<Inan,Loc,Masc,Sing>, lemma='ход'), DocToken(start=26, stop=34, text='обстрела', id='1_6', head_id='1_3', rel='obl', pos='NOUN', feats=<Inan,Gen,Masc,Sing>, lemma='обстрел'), DocToken(start=35, stop=43, text='Шебекина', id='1_7', head_id='1_6', rel='nmod', pos='PROPN', feats=<Anim,Nom,Masc,Sing>, lemma='шебекино'), DocToken(start=43, stop=44, text='.', id='1_8', head_id='1_3', rel='punct', 
# ...

# %%
doc.tag_ner(ner_tagger)
print(doc.spans)
doc.ner.print()
# Out:
# [DocSpan(start=35, stop=43, type='PER', text='Шебекина', tokens=[...]), DocSpan(start=47, stop=53, type='LOC', text='России', tokens=[...]), DocSpan(start=69, stop=82, type='PER', text='Юрия Гагарина', tokens=[...]), DocSpan(start=90, stop=93, type='ORG', text='РАН', tokens=[...]), DocSpan(start=248, stop=255, type='LOC', text='Косовом', tokens=[...]), DocSpan(start=267, stop=273, type='LOC', text='Канады', tokens=[...]), DocSpan(start=282, stop=288, type='LOC', text='финаЫл', tokens=[...]), DocSpan(start=428, stop=447, type='LOC', text='Ульяновской области', tokens=[...]), DocSpan(start=450, stop=456, type='PER', text='Песков', tokens=[...]), DocSpan(start=458, stop=463, type='LOC', text='Запад', tokens=[...]), DocSpan(start=502, stop=505, type='ORG', text='СВО', tokens=[...]), DocSpan(start=563, stop=584, type='LOC', text='Комсомольске-на-Амуре', tokens=[...]), DocSpan(start=586, stop=593, type='LOC', text='Украина', tokens=[...]), DocSpan(start=630, stop=647, type='ORG', text='Чер
# ...

# %%
for span in doc.spans:
    span.normalize(morph_vocab)
print(doc.spans)
{_.text: _.normal for _ in doc.spans if _.text != _.normal}
# Out:
# [DocSpan(start=35, stop=43, type='PER', text='Шебекина', tokens=[...], normal='Шебекина'), DocSpan(start=47, stop=53, type='LOC', text='России', tokens=[...], normal='Россия'), DocSpan(start=69, stop=82, type='PER', text='Юрия Гагарина', tokens=[...], normal='Юрий Гагарин'), DocSpan(start=90, stop=93, type='ORG', text='РАН', tokens=[...], normal='РАН'), DocSpan(start=248, stop=255, type='LOC', text='Косовом', tokens=[...], normal='Косовом'), DocSpan(start=267, stop=273, type='LOC', text='Канады', tokens=[...], normal='Канада'), DocSpan(start=282, stop=288, type='LOC', text='финаЫл', tokens=[...], normal='финаЫл'), DocSpan(start=428, stop=447, type='LOC', text='Ульяновской области', tokens=[...], normal='Ульяновская область'), DocSpan(start=450, stop=456, type='PER', text='Песков', tokens=[...], normal='Песков'), DocSpan(start=458, stop=463, type='LOC', text='Запад', tokens=[...], normal='Запад'), DocSpan(start=502, stop=505, type='ORG', text='СВО', tokens=[...], normal='СВО'), DocSpa
# ...

# %%
for span in doc.spans:
    if span.type == PER:
       span.extract_fact(names_extractor)
print(doc.spans)
{_.text: _.normal for _ in doc.spans if _.type == PER}
# Out:
# [DocSpan(start=35, stop=43, type='PER', text='Шебекина', tokens=[...], normal='Шебекина'), DocSpan(start=47, stop=53, type='LOC', text='России', tokens=[...], normal='Россия'), DocSpan(start=69, stop=82, type='PER', text='Юрия Гагарина', tokens=[...], normal='Юрий Гагарин', fact=DocFact(slots=[...])), DocSpan(start=90, stop=93, type='ORG', text='РАН', tokens=[...], normal='РАН'), DocSpan(start=248, stop=255, type='LOC', text='Косовом', tokens=[...], normal='Косовом'), DocSpan(start=267, stop=273, type='LOC', text='Канады', tokens=[...], normal='Канада'), DocSpan(start=282, stop=288, type='LOC', text='финаЫл', tokens=[...], normal='финаЫл'), DocSpan(start=428, stop=447, type='LOC', text='Ульяновской области', tokens=[...], normal='Ульяновская область'), DocSpan(start=450, stop=456, type='PER', text='Песков', tokens=[...], normal='Песков', fact=DocFact(slots=[...])), DocSpan(start=458, stop=463, type='LOC', text='Запад', tokens=[...], normal='Запад'), DocSpan(start=502, stop=505, type=
# ...

# %%
print(type(arr_data3))

# %%
temp = bs.find('div', 'list__item')

# %%
print(temp)
# Out:
# <div class="list__item">
# <a class="list__pic-wrapper vgtrk-lazy-preloader" href="/auto/article/3375027">
# <img alt="В Госдуме предлагают смягчить правила парковки в Москве" class="list__pic vgtrk-lazy" data-src="https://cdn-st1.rtr-vesti.ru/vh/pictures/lw/405/691/0.jpg"/>
# </a>
# <div class="list__info">
# <div class="list__data">
# <div class="list__date">
#                                     27 мая 2023
#                                 </div>
# <div class="list__time">
#                                     15:44
#                                 </div>
# <div class="list__subtitle">
# <a href="/auto" target="_blank">
# <span class="list__src">Авто</span>
# </a>
# </div>
# </div>
# <h3 class="list__title">
# <a href="/auto/article/3375027">В Госдуме предлагают смягчить правила парковки в Москве</a>
# </h3>
# </div>
# </div>

# %%
temp = bs.find('div', 'list__date')

# %%
temp
# Out:
# <div class="list__date">
#                                     27 мая 2023
#                                 </div>

# %%
print(temp.text)
# Out:
#                                     27 мая 2023

# %%
temp = bs.find('div', 'list__time')

# %%
print(temp.text)
# Out:
#                                     15:44

# %%
temp = bs.find('h3', 'list__title')

# %%
temp
# Out:
# <h3 class="list__title">
# <a href="/auto/article/3375027">В Госдуме предлагают смягчить правила парковки в Москве</a>
# </h3>

# %%
print(temp.text)
# Out:
# В Госдуме предлагают смягчить правила парковки в Москве
